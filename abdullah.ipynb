# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# get_description() is a function to get the description of any column name or a value.
# It takes the column/value name, or any list of them:
from data_description import get_description

# %matplotlib inline
sns.set_style('darkgrid')

# %%
df = pd.read_csv('data/train.csv')

# %%
target = df['SalePrice']
target
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
feat_set4 = df.iloc[:, 49:65]
feat_set4
# Out:
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# ...        ...       ...           ...           ...         ...
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0         NaN     Attchd       2003.0
# ...

# %%
feat_set4.reset_index()
feat_set4['SalePrice'] = target

# %%
feat_set4
# Out:
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# ...        ...       ...           ...           ...         ...
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0         NaN     Attchd       2003.0
# ...

# %%
feat_set4.describe()
# Out:
#           FullBath     HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# count  1460.000000  1460.000000   1460.000000   1460.000000   1460.000000
# mean      1.565068     0.382877      2.866438      1.046575      6.517808
# std       0.550916     0.502885      0.815778      0.220338      1.625393
# min       0.000000     0.000000      0.000000      0.000000      2.000000
# 25%       1.000000     0.000000      2.000000      1.000000      5.000000
# 50%       2.000000     0.000000      3.000000      1.000000      6.000000
# 75%       2.000000     1.000000      3.000000      1.000000      7.000000
# max       3.000000     2.000000      8.000000      3.000000     14.000000
#
#         Fireplaces  GarageYrBlt   GarageCars   GarageArea      SalePrice
# count  1460.000000  1379.000000  1460.000000  1460.000000    1460.000000
# mean      0.613014  1978.506164     1.767123   472.980137  180921.195890
# std       0.644666    24.689725     0.747315   213.804841   79442.502883
# ...

# %%
feat_set4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   FullBath      1460 non-null   int64
#  1   HalfBath      1460 non-null   int64
#  2   BedroomAbvGr  1460 non-null   int64
#  3   KitchenAbvGr  1460 non-null   int64
#  4   KitchenQual   1460 non-null   object
#  5   TotRmsAbvGrd  1460 non-null   int64
#  6   Functional    1460 non-null   object
#  7   Fireplaces    1460 non-null   int64
#  8   FireplaceQu   770 non-null    object
#  9   GarageType    1379 non-null   object
#  10  GarageYrBlt   1379 non-null   float64
#  11  GarageFinish  1379 non-null   object
#  12  GarageCars    1460 non-null   int64
#  13  GarageArea    1460 non-null   int64
#  14  GarageQual    1379 non-null   object
#  15  GarageCond    1379 non-null   object
#  16  SalePrice     1460 non-null   int64
# dtypes: float64(1), int64(9), object(7)
# ...

# %%
import seaborn as sns

plt.figure(figsize=(15,15))
sns.heatmap(feat_set4.corr(), square=True, annot=True, linewidths=.5)
plt.title("Correlation matrix among winsorized variables")
plt.show()

# %%
# Replace multiple values in a specific column
replacement_dict = {'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, 'Po': 1}
replacement_dict1 = {'Fin': 3, 'RFn': 2, 'Unf': 1}
feat_set4['KitchenQual'] = feat_set4['KitchenQual'].replace(replacement_dict)
feat_set4['FireplaceQu'] = feat_set4['FireplaceQu'].replace(replacement_dict)
feat_set4['GarageFinish'] = feat_set4['GarageFinish'].replace(replacement_dict1)
feat_set4['GarageQual'] = feat_set4['GarageQual'].replace(replacement_dict)
feat_set4['GarageCond'] = feat_set4['GarageCond'].replace(replacement_dict)

# %%
feat_set4['FireplaceQu'] = feat_set4['FireplaceQu'].fillna(0).astype('int64')
feat_set4['GarageType'] = feat_set4['GarageType'].fillna('NG')
feat_set4['GarageYrBlt'] = feat_set4['GarageYrBlt'].fillna(0).astype('int64')
feat_set4['GarageFinish'] = feat_set4['GarageFinish'].fillna(0).astype('int64')
feat_set4['GarageQual'] = feat_set4['GarageQual'].fillna(0).astype('int64')
feat_set4['GarageCond'] = feat_set4['GarageCond'].fillna(0).astype('int64')

# %%
feat_set4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   FullBath      1460 non-null   int64
#  1   HalfBath      1460 non-null   int64
#  2   BedroomAbvGr  1460 non-null   int64
#  3   KitchenAbvGr  1460 non-null   int64
#  4   KitchenQual   1460 non-null   int64
#  5   TotRmsAbvGrd  1460 non-null   int64
#  6   Functional    1460 non-null   object
#  7   Fireplaces    1460 non-null   int64
#  8   FireplaceQu   1460 non-null   int64
#  9   GarageType    1460 non-null   object
#  10  GarageYrBlt   1460 non-null   int64
#  11  GarageFinish  1460 non-null   int64
#  12  GarageCars    1460 non-null   int64
#  13  GarageArea    1460 non-null   int64
#  14  GarageQual    1460 non-null   int64
#  15  GarageCond    1460 non-null   int64
#  16  SalePrice     1460 non-null   int64
# dtypes: int64(15), object(2)
# memory usage: 194.0+ KB

# %%
feat_set4
# Out:
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  \
# 0            2         1             3             1            4
# 1            2         0             3             1            3
# 2            2         1             3             1            4
# 3            1         0             3             1            4
# 4            2         1             4             1            4
# ...        ...       ...           ...           ...          ...
# 1455         2         1             3             1            3
# 1456         2         0             3             1            3
# 1457         2         0             4             1            4
# 1458         1         0             2             1            4
# 1459         1         1             3             1            3
#
#       TotRmsAbvGrd Functional  Fireplaces  FireplaceQu GarageType  \
# 0                8        Typ           0            0     Attchd
# ...

# %%
feat_set4.isnull().sum()
# Out:
# FullBath        0
# HalfBath        0
# BedroomAbvGr    0
# KitchenAbvGr    0
# KitchenQual     0
# TotRmsAbvGrd    0
# Functional      0
# Fireplaces      0
# FireplaceQu     0
# GarageType      0
# GarageYrBlt     0
# GarageFinish    0
# GarageCars      0
# GarageArea      0
# GarageQual      0
# GarageCond      0
# SalePrice       0
# dtype: int64

# %%
import seaborn as sns

plt.figure(figsize=(15,15))
sns.heatmap(feat_set4.corr(), square=True, annot=True, linewidths=.5)
plt.title("Correlation matrix among winsorized variables")
plt.show()

# %%
columns = feat_set4.columns.to_list()
columns
# Out:
# ['FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond',
#  'SalePrice']

# %%
plt.figure(figsize=(15,75))

for i in range(len(columns)):
    plt.subplot(18,2,i+1)
    plt.hist(feat_set4[columns[i]])
    plt.title(columns[i])

plt.show()

# %%
plt.figure(figsize=(18,40))

for i, col in enumerate(columns):
    if col != 'SalePrice':
        plt.subplot(8,2,i+1)
        plt.scatter(feat_set4["SalePrice"], feat_set4[col])
        plt.title(f"SalePrice vs {col}")

# %%
func_df = feat_set4.groupby('Functional')[feat_set4.columns].mean()
func_df = pd.DataFrame(func_df)
func_df.reset_index(inplace= True)
func_df
# Out:
#   Functional  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  \
# 0       Maj1  1.857143  0.214286      3.000000      1.071429     3.428571
# 1       Maj2  1.000000  0.000000      2.200000      1.000000     3.000000
# 2       Min1  1.387097  0.161290      2.677419      1.032258     3.096774
# 3       Min2  1.441176  0.382353      3.205882      1.088235     3.235294
# 4        Mod  1.733333  0.266667      3.266667      1.200000     3.133333
# 5        Sev  2.000000  1.000000      3.000000      1.000000     3.000000
# 6        Typ  1.569118  0.391912      2.858824      1.044118     3.535294
#
#    TotRmsAbvGrd  Fireplaces  FireplaceQu  GarageYrBlt  GarageFinish  \
# 0      7.500000    0.714286     1.785714  1555.928571      1.214286
# 1      5.200000    0.400000     0.600000  1556.000000      1.000000
# 2      6.580645    0.741935     1.838710  1961.258065      1.419355
# 3      6.823529    0.647059     1.764706  1848.264706      1.411765
# ...

# %%
func_df.plot.bar(x='Functional', y='SalePrice', rot=0)

# Add labels and title
plt.xlabel('Functional')
plt.ylabel('SalePrice')
plt.title('Functional Vs. SalePrice')

# Display the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Functional', y='SalePrice', data=func_df)
plt.xlabel("Functional");
plt.ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
grg_df = feat_set4.groupby('GarageType')[feat_set4.columns].mean()
grg_df = pd.DataFrame(grg_df)
grg_df.reset_index(inplace= True)
grg_df
# Out:
#   GarageType  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  \
# 0     2Types  1.666667  0.333333      3.666667      1.500000     3.333333
# 1     Attchd  1.670115  0.413793      2.840230      1.014943     3.660920
# 2    Basment  1.421053  0.105263      3.000000      1.000000     3.157895
# 3    BuiltIn  2.068182  0.875000      3.409091      1.022727     4.022727
# 4    CarPort  1.333333  0.444444      2.111111      1.444444     3.000000
# 5     Detchd  1.279070  0.260982      2.795866      1.080103     3.214470
# 6         NG  1.308642  0.160494      2.888889      1.185185     2.925926
#
#    TotRmsAbvGrd  Fireplaces  FireplaceQu  GarageYrBlt  GarageFinish  \
# 0      7.166667    0.500000     1.000000  1965.666667      1.666667
# 1      6.589655    0.744828     2.204598  1984.275862      2.056322
# 2      6.473684    0.894737     2.157895  1962.473684      1.736842
# 3      8.227273    0.920455     3.102273  1996.829545      2.613636
# ...

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='GarageType', y='SalePrice', data=grg_df)
plt.xlabel("GarageType");
plt.ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
grg_df.plot.bar(x='GarageType', y='SalePrice', rot=0)

# Add labels and title
plt.xlabel('GarageType')
plt.ylabel('SalePrice')
plt.title('GarageType Vs. SalePrice')

# Display the plot
plt.show()

# %%
columns = feat_set4.select_dtypes(include=['number']).columns.tolist()
columns
# Out:
# ['FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageCars',
#  'GarageArea',
#  'GarageQual',
#  'GarageCond',
#  'SalePrice']

# %%
plt.figure(figsize=(20,30))

for i, variable in enumerate(columns):
                     plt.subplot(5,4,i+1)
                     plt.boxplot(feat_set4[variable],whis=1.5)
                     plt.title(variable)

plt.show()
